# %% [markdown]
# # opencv course
# # A presentation by Mohammad Kahkeshani
# ### instagram:
# #### codevision_academy
# #### kahkeshani_mohammad

# %% [markdown]
# ### Make a brush

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Creating a global variable
draw = False # True if mouse is pressed

# callback function
def brush(event, x, y, falgs, param): # you have to memorize this
    global draw
    if event == cv2.EVENT_LBUTTONDOWN:
        draw = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if draw == True:
            cv2.circle(img,(x,y),5,(255,0,0), -1)
    elif event == cv2.EVENT_LBUTTONUP:
        draw = False

img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image', brush)

while True:
    cv2.imshow('image', img)
    if cv2.waitKey(1) & 0xFF == 27:
        break
cv2.destroyAllWindows()
plt.imshow(img[...,::-1])

# %% [markdown]
# ### Change the pen color

# %%
draw = False
color = (255,0,0)

def brush(event, x, y, flags, param):
    global draw, color
    if event == cv2.EVENT_LBUTTONDOWN:
        draw = True
    elif event == cv2.EVENT_MOUSEMOVE:
        if draw == True:
            cv2.circle(img,(x,y), 5, color, -1)
    elif event == cv2.EVENT_LBUTTONUP:
        draw = False
        
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image', brush)

while True:
    cv2.imshow('image', img)
    key = cv2.waitKey(1) & 0xFF 
    if key == ord('b'): # ord returns ASCII code 
        color = (255,0,0)
    elif key == ord('g'):
        color =(0,255,0)
    elif key == ord('r'):
        color = (0,0,255)
    elif key == 27 & 0xFF:
        break
cv2.destroyAllWindows()
plt.imshow(img[...,::-1])
