# %% [markdown]
# # opencv course
# # A presentation by Mohammad Kahkeshani
# ### instagram:
# #### codevision_academy
# #### kahkeshani_mohammad

# %% [markdown]
# ### Sobel

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('images/little_girl.jpg',0)

# Extract Sobel Edges
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=5)

final_sobel = cv2.add(sobel_x, sobel_y)

plt.figure(figsize=[12,7])
plt.subplot(231);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(234);plt.imshow(sobel_x, cmap='gray');plt.title("sobel X");
plt.subplot(235);plt.imshow(sobel_y, cmap='gray');plt.title("sobel Y");
plt.subplot(236);plt.imshow(final_sobel, cmap='gray');plt.title("Final");

# %% [markdown]
# ### از آنجا که مشتق می‌تواند منفی یا مثبت باشد (مثلاً تغییر از روشن به تیره یا برعکس)، نتیجه‌ی خام ممکن است شامل مقادیر منفی باشد که در نمایش تصویر درست دیده نمی‌شوند.
#
# با گرفتن قدرمطلق، فقط شدت تغییرات باقی می‌ماند و علامت منفی حذف می‌شود. این کار باعث می‌شود لبه‌ها به‌صورت روشن روی تصویر قابل‌مشاهده باشن.

# %% [markdown]
# ### Using abs

# %%
image = cv2.imread('images/little_girl.jpg',0)

# Extract Sobel Edges
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

sobel_x = np.abs(sobel_x)
sobel_y = np.abs(sobel_y)
final_sobel = cv2.add(sobel_x, sobel_y)


plt.figure(figsize=[12,7])
plt.subplot(231);plt.imshow(image, cmap='gray');plt.title("Original");
plt.subplot(234);plt.imshow(sobel_x, cmap='gray');plt.title("sobel X");
plt.subplot(235);plt.imshow(sobel_y, cmap='gray');plt.title("sobel Y");
plt.subplot(236);plt.imshow(final_sobel, cmap='gray');plt.title("Final");

# %%
src = cv2.imread("images/little_girl.jpg",)

src = cv2.GaussianBlur(src, (3, 3), 0)

gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)


grad_x = cv2.Sobel(gray, cv2.CV_16S, 1, 0, ksize=3)
grad_y = cv2.Sobel(gray, cv2.CV_16S, 0, 1, ksize=3)


abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)

grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)


plt.figure(figsize=[12,7])
plt.subplot(231);plt.imshow(src[...,::-1]);plt.title("Original");
plt.subplot(234);plt.imshow(abs_grad_x, cmap='gray');plt.title("grad x");
plt.subplot(235);plt.imshow(abs_grad_y, cmap='gray');plt.title("grad y");
plt.subplot(236);plt.imshow(grad, cmap='gray');plt.title("final grad");

# %% [markdown]
# ### Laplacian

# %%
src = cv2.imread("images/little_girl.jpg") 

# Remove noise by blurring with a Gaussian filter
src = cv2.GaussianBlur(src, (3, 3), 0)

src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

dst = cv2.Laplacian(src_gray, cv2.CV_16S, ksize=3)

abs_dst = cv2.convertScaleAbs(dst)


plt.figure(figsize=[12,7])
plt.subplot(121);plt.imshow(src[...,::-1]);plt.title("Original");
plt.subplot(122);plt.imshow(abs_dst, cmap='gray');plt.title("Laplacian");

# %% [markdown]
# ### Canny

# %%
import cv2
import matplotlib.pyplot as plt

src = cv2.imread("images/little_girl.jpg")


gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)


blur = cv2.GaussianBlur(gray, (5, 5), 1)


edges = cv2.Canny(blur, 100, 200)


plt.figure(figsize=[15,8])
plt.subplot(141); plt.imshow(src[..., ::-1]); plt.title('Original Image')
plt.subplot(142); plt.imshow(gray, cmap='gray'); plt.title('Grayscale')
plt.subplot(143); plt.imshow(blur, cmap='gray'); plt.title('Gaussian Blur')
plt.subplot(144); plt.imshow(edges, cmap='gray'); plt.title('Canny Edges')
plt.show()
